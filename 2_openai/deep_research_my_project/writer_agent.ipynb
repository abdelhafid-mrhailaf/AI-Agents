# %%
from pydantic import BaseModel, Field
from agents import Agent, Runner
from dotenv import load_dotenv


load_dotenv(override=True)

INSTRUCTIONS = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words."
)


class ReportData(BaseModel):
    short_summary: str = Field(description="A short 2-3 sentence summary of the findings.")

    markdown_report: str = Field(description="The final report")

    follow_up_questions: list[str] = Field(description="Suggested topics to research further")


writer_agent = Agent(
    name="WriterAgent",
    instructions=INSTRUCTIONS,
    model="gpt-4o-mini",
    output_type=ReportData,
)

# %%
from dis import Instruction
from pyexpat import model


class ReportDataValidator(BaseModel):
    is_completed: bool = Field(description="When it is completed it is gonna return true")
    accuracy_score: str = Field(description="The score from 0 to 10, when the score is above 8 the search is acceptable")
    

VALIDATOR_INSTRUCTIONS = (
    "You are a senior reviewer responsible for validating a research report produced by another agent. "
    "You will receive the original query, any assistant notes, and the final report.\n"
    "Your task is to assess the report’s accuracy, completeness, coherence, and alignment with the query’s intent. "
    "Identify factual errors, logical gaps, or unsupported claims.\n"
    "After your evaluation, you must output a JSON object that matches the following schema:\n\n"
    "{\n"
    '  "is_completed": bool,  // True if validation is done\n'
    '  "accuracy_score": str  // A score from 0 to 10, where scores above 8 indicate acceptable accuracy\n'
    "}\n\n"
    "Before generating the JSON, write a concise markdown evaluation that includes: "
    "1) Summary of purpose, "
    "2) Strengths, "
    "3) Weaknesses, "
    "4) Suggestions for improvement, "
    "and 5) Overall verdict.\n"
    "Be objective, precise, and professional. Focus on factual accuracy and logical consistency. "
    "Keep your evaluation between 600–1000 words. "
    "Finally, append the JSON object in a code block as your output."
)

writer_validator_agent = Agent(
    name = "Writer Validator Agent",
    instructions = VALIDATOR_INSTRUCTIONS,
    model = "gpt-4o-mini",
    output_type = ReportDataValidator
)

# %%
research = "\n\n".join(
    open(f"summary{i}.md", encoding="utf-8").read()
    for i in range(1, 4)
)

query = "What are the most useful frameworks for developing AI Chatbots that help IT help-desks solve their daily tasks"

# %%
async def perform_write(query: str, research: list[str], history=""):
    researches = " ".join(research)
    result = await Runner.run(
        writer_agent,
        f"Query: {query}, research: {researches}, the history in the case it was not validated throw the validator: {history}"
    )
    return result.final_output_as(ReportData)


raport  = await perform_write(query, research)

with open("raport.md", "w", encoding="utf-8") as out:
    out.write(raport.markdown_report)

# %%
async def evaluate_raport(query: str, raport: ReportData):
    "the original query, any assistant notes, and the final report."
    assistantNote = raport.short_summary
    finalReport = raport.markdown_report

    evaluation = await Runner.run(
        writer_validator_agent,
        f"This is the Query: {query}, assistant Note: {assistantNote}, final Report: {finalReport}"
    )
    return evaluation.final_output_as(ReportDataValidator)


async def report_writer(query: str, research: list[str]):
    raport = await perform_write(query, research)
    raportEvaluation = await evaluate_raport(query, raport)
    history = ""
    EXTEND_LIMIT_OF_CALL = 0
    raportEvaluation.is_completed = False
    while (not raportEvaluation.is_completed  and (EXTEND_LIMIT_OF_CALL < 10)) or (int(raportEvaluation.accuracy_score) < 8 and (EXTEND_LIMIT_OF_CALL < 10)):
        print("Inside the loop")
        raport = await perform_write(query, research)
        raportEvaluation = await evaluate_raport(query, raport)
        EXTEND_LIMIT_OF_CALL += 1
    return raport

#print(await evaluate_raport(query, raport))   
raport_evaluated = await report_writer(query, research)
print(raport_evaluated.markdown_report)
# Out:
# Inside the loop
# # Frameworks for Developing AI Chatbots in IT Help Desks
#
# ## Introduction
# As technology continues to evolve, IT help desks are increasingly turning to artificial intelligence (AI) chatbots to streamline operations, enhance user experience, and reduce response times. These chatbots can automate repetitive tasks, facilitate user interactions, and provide immediate assistance. This report explores various frameworks that support the development of AI chatbots tailored for IT help desks, highlighting the unique features, strengths, and applications of each framework.
#
# ## Framework Overview
# When selecting a framework for AI chatbot development, organizations must consider various factors such as customization, scalability, integration capabilities, and specific use cases. Below, we present several prominent frameworks suited for IT help desk applications:
#
# ### 1. Botpress
# **Description**: Botpress is an open-source platform designed for the creation of AI-driven support bots. Known for its comprehensive toolkit, it allows developers to design, train, and deploy chatbots seamlessly.
#
# **Key Features**:
# - **Visual Drag-and-Drop Studio**: Facilitates custom conversation flow design without extensive coding knowledge.
# - **Integration with Popular AI Models**: Connectivity with advanced models like OpenAI's GPT-4 for enhanced understanding and response generation.
# - **Multi-channel Deployment**: Options to deploy across various platforms, including Messenger and WhatsApp.
# - **Analytics Capabilities**: Provides insights to improve user intent recognition and bot performance.
#
# **Suitability**: Ideal for organizations looking for a customizable solution that supports a range of user interactions across different channels.
#
# ### 2. Rasa
# **Description**: Rasa is a powerful open-source Python library emphasizing machine learning-based dialogue management.
#
# **Key Features**:
# - **Rasa NLU**: Offers natural language understanding to process and understand user queries effectively.
# - **Rasa Core**: Manages dialogue flow based on user inputs through machine learning techniques.
# - **Ease of Use**: Designed for developers with minimal initial training data, making it easier to get started.
#
# **Suitability**: Particularly well-suited for developers who want flexibility and control over the customization and training processes of their chatbots.
#
# ### 3. Microsoft Bot Framework
# **Description**: The Microsoft Bot Framework facilitates holistic chatbot development, allowing organizations to connect, publish, and manage chatbots across diverse channels.
#
# **Key Features**:
# - **Multi-channel Support**: Connects to platforms like Skype, Slack, and Facebook Messenger, ensuring broad accessibility.
# - **Integration with Cognitive Services**: Enhances chatbot capabilities with advanced AI features.
# - **Support for Multiple Programming Languages**: Provides versatility for developers familiar with various coding languages.
#
# **Suitability**: Best for organizations already invested in the Microsoft ecosystem or those requiring robust multi-channel integration.
#
# ### 4. IBM Watson Assistant
# **Description**: IBM Watson Assistant is a flexible chatbot framework that offers deep integration with cloud services and AI tools.
#
# **Key Features**:
# - **Natural Language Processing (NLP)**: Delivers advanced NLP capabilities for understanding user intents and contexts.
# - **Customization Options**: Allows for extensive chatbot personalization and function tailoring.
# - **Scalable Solutions**: Works well in large-scale deployments, handling varying levels of load and complexity.
#
# **Suitability**: Ideal for enterprises needing comprehensive AI-driven solutions capable of handling substantial user interactions and complex requirements.
#
# ### 5. Zendesk Answer Bot
# **Description**: Part of Zendesk's suite of support tools, the Answer Bot leverages AI to suggest relevant articles and solve basic user queries autonomously.
#
# **Key Features**:
# - **Seamless Integration**: Works within Zendesk's existing ticketing and knowledge base systems.
# - **Autonomous Issue Resolution**: Capable of addressing standard queries without human intervention.
#
# **Suitability**: Suitable for organizations already using Zendesk for support, emphasizing ease of use and quick deployment.
#
# ## Other Notable Frameworks
# In addition to the frameworks mentioned above, several others may also fit specific needs:
#
# - **Agentiive AI Q**: A no-code platform featuring rapid deployment capabilities through technologies like Retrieval-Augmented Generation (RAG).
# - **MoveWorks**: Focuses on natural language understanding to enable automatic request resolutions in collaboration tools.
# - **Aisera**: Combines conversational AI with workflow automation, allowing for autonomous task management and issue prediction.
# - **Light Agent**: An open-source framework for building versatile chatbots with core functionalities.
# - **LangChain & NeMo**: Provide modular tools for customizing AI applications and managing multiple Large Language Model components efficiently.
#
# ## Automation Benefits of AI Chatbots
# Integrating AI chatbots in IT help desks can lead to transformative benefits:
# - **Time Efficiency**: Reduces response times by providing instant answers to common queries.
# - **Cost Reduction**: Lowers operational costs by automating repetitive tasks and reducing manpower needs for mundane queries.
# - **Improved User Experience**: Enhances user satisfaction through timely assistance and availability.
#
# ## Considerations for Choosing the Right Framework
# Choosing the appropriate framework requires a careful assessment of several factors:
# - **Integration Capability**: How well does the framework integrate with existing systems and workflows?
# - **Customization Needs**: Does the framework allow for sufficient customization to meet specific organizational requirements?
# - **Scalability**: Can the framework support future growth in user queries and interaction volumes?
# - **Technical Expertise**: What is the skill level of the development team, and do they possess the knowledge needed to work with the chosen framework?
#
# ## Conclusion
# AI chatbot frameworks offer powerful solutions for enhancing IT help desk operations. Selecting the right one involves understanding both organizational needs and the unique features of each framework. As these technologies continue to evolve, ongoing assessments and updates will be crucial for maximizing the potential benefits of AI-driven customer support.
#
# ## Follow-up Questions
# - What specific features would enhance user experience in an IT help desk environment?
# - How do current implementations of these frameworks across various organizations compare in effectiveness?
# - What measures can ensure the security and data privacy of users interacting with AI chatbots?
